# %% [markdown]
# <a href="https://colab.research.google.com/github/aiswaryaks411/ds/blob/main/datascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  import pandas as pd

# %%
df=pd.read_csv("/content/Iris.csv")
print(df)
print(df.head())
print(df.tail())
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print(df.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
print(df['PetalLengthCm'])
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
print(df[['PetalLengthCm','SepalLengthCm']])
# Out:
#      PetalLengthCm  SepalLengthCm
# 0              1.4            5.1
# 1              1.4            4.9
# 2              1.3            4.7
# 3              1.5            4.6
# 4              1.4            5.0
# ..             ...            ...
# 145            5.2            6.7
# 146            5.0            6.3
# 147            5.2            6.5
# 148            5.4            6.2
# 149            5.1            5.9
#
# [150 rows x 2 columns]

# %%
print(df[df['SepalLengthCm']>5])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 10    11            5.4           3.7            1.5           0.2
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 5       Iris-setosa
# 10      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# ..              ...
# ...

# %%
print(df['Species'].unique())
print(df['Species'].value_counts())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
print(df.isnull())
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
import matplotlib.pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May"]
x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]

plt.plot(months, x, marker='o', linestyle='--', label="Product A")
plt.plot(months, y, marker='s', linestyle='-', label="Product B")
plt.barh(x, y)
plt.title("Monthly Sales")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)

plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]

plt.barh(x, y)
plt.title("Monthly Sales")
plt.xlabel("Months")
plt.ylabel("Sales")

plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
salary = [20,22,25,25,28,30,32,35,40,45]
plt.hist(salary, bins=5)
plt.title("Employee Salary Distribution")
plt.xlabel("salary(Thousand)")
# Out:
# Text(0.5, 0, 'salary(Thousand)')

# %%
hours=[1,2,3,4,5,6]
marks=[45,50,60,65,75,85]
plt.scatter(hours,marks)
plt.title("Study Hours vs Marks")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.show()

# %%
subject=["Python","Java","DBMS","AI"]
students=[30,25,20,25]
plt.pie(students, labels=subject,autopct='%1.1f%%')
plt.title("Student Interested by subject")
plt.show()

# %%
marks=[45,50,52,55,60,62,65,68,70,150]
plt.boxplot(marks)
plt.title("Student Marks - Outlier Detection")
plt.ylabel("marks")
plt.show()

# %%
x=[1,2,3,4,5]
y1=[10,20,30,40,50]
y2=[50,40,30,20,10]
plt.subplot(1,2,1)
plt.plot(x,y1)
plt.title("Increasing")
plt.subplot(1,2,2)
plt.plot(x,y2)
plt.title("Decreasing")
plt.show()

# %%
x=[1,2,6,18]
y=[3,10,12,20]
plt.plot(x,y,'r:',marker='o',mfc='green',mec='darkgreen')
plt.grid(True)
plt.show()

# %%
x=[2001,2002,2003,2004,2005,2006,2007]
y=[24000,22500,19700,17500,14500,10000,5800]
plt.plot(x,y,'r-.',mfc='green',mec='green',marker='*',markersize=20)
plt.xlabel('Year')
plt.ylabel('Car Value')
plt.title('Value depreciation',loc='left')
plt.show()

# %%
m=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
a=[173,153,195,147,120,144,148,109,174,130,172,131]
l=[189,189,105,112,173,109,151,197,174,145,177,161]
s=[185,185,126,134,196,153,112,133,200,145,167,110]
plt.scatter(m,a,color='pink')
plt.scatter(m,l,color='yellow')
plt.scatter(m,s,color='blue')
plt.xlabel('Months of Year',fontsize=18)
plt.ylabel('Sales of Segments')
plt.title('Sales Data')
plt.show()

# %%
#a
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/Iris.csv')
print(df.head())
plt.scatter(df['SepalLengthCm'], df['SepalWidthCm'])
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#c
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/Iris.csv')

# Strip any whitespace from the 'Species' column
df['Species'] = df['Species'].str.strip()

colors = {"setosa":"red","versicolor":"green","virginica":"blue"}
for flower in colors:
    data = df[df["Species"] == 'Iris-'+flower]
    plt.scatter(data["SepalLengthCm"], data["SepalWidthCm"],
                color=colors[flower], label=flower)
plt.legend()
plt.show()

# %%
#d
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/Iris.csv')
plt.plot(df["SepalLengthCm"], df["SepalWidthCm"])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

# %%
#e
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/Iris.csv')
plt.hist(df["SepalLengthCm"])
plt.xlabel("Sepal Length")
plt.show()

# %%
#f---
import pandas as pd
import matplotlib.pyplot as pl
df = pd.read_csv('/content/Iris.csv')
data = df.groupby("Species")["SepalLengthCm"].sum()
plt.bar(data.index, data.values)
plt.show()

# %%
#g---
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/Iris.csv")
df.boxplot(column="SepalLengthCm", by="Species")
plt.show()

# %%
#h---
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/Iris.csv")
count = df["Species"].value_counts()
plt.pie(count, labels=count.index, autopct="%1.1f%%")
plt.show()

# %%
#i---
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/Iris.csv")

# Strip any whitespace from the 'Species' column
df['Species'] = df['Species'].str.strip()

colors = {"setosa":"red","versicolor":"green","virginica":"blue"}
for flower in colors:
    data = df[df["Species"] == 'Iris-'+flower]
    plt.scatter(data["PetalLengthCm"], data["PetalWidthCm"],
                color=colors[flower], label=flower)
plt.legend()
plt.show()

# %%
#j---
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/Iris.csv")
plt.subplot(2,2,1)
plt.hist(df["SepalLengthCm"])
plt.subplot(2,2,2)
plt.hist(df["SepalWidthCm"])
plt.subplot(2,2,3)
plt.hist(df["PetalLengthCm"])
plt.subplot(2,2,4)
plt.hist(df["PetalWidthCm"])
plt.tight_layout()
plt.show()

# %%
#k-----
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/Iris.csv")
avg = df.groupby("Species")[["SepalLengthCm","SepalWidthCm"]].mean()
avg.plot(kind="bar")
plt.show()

# %%
#l--
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/Iris.csv")
plt.scatter(df["PetalLengthCm"],
            df["PetalWidthCm"],
            s=df["SepalLengthCm"]*20)
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.show()

# %%
#5-1
import pandas as pd
import numpy as np
series1 = pd.Series([1, 3, 5, 6, 8])
print("1. Pandas Series:")
print(series1)
# Out:
# 1. Pandas Series:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
#5-2
data = {
    "Country": ["Brazil", "Russia", "India", "China", "South Africa"],
    "Capital": ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
    "Area": [8515767, 17098242, 3287263, 9596961, 1221037],
    "Population": [212559417, 145912025, 1380004385, 1444216107, 59308690]
}
brics = pd.DataFrame(
    data,
    index=["BR", "RU", "IN", "CH", "SA"]
)
print("\n2. BRICS DataFrame:")
print(brics)
# Out:
# 2. BRICS DataFrame:
#          Country    Capital      Area  Population
# BR        Brazil   Brasilia   8515767   212559417
# RU        Russia     Moscow  17098242   145912025
# IN         India  New Delhi   3287263  1380004385
# CH         China    Beijing   9596961  1444216107
# SA  South Africa   Pretoria   1221037    59308690

# %%
#5-3
cars = pd.read_csv("cars1.csv")
# Display complete dataset
print("\n3(a). Complete cars1.csv dataset:")
print(cars)
# Display first four records
print("\n3(b). First four records:")
print(cars.head(4))
# Display fifth and sixth records
print("\n3(c). Fifth and sixth records:")
print(cars.iloc[4:6])
# Display third row using iloc[]
print("\n3(d). Third row using iloc[]:")
print(cars.iloc[2])
# Out:
# 3(a). Complete cars1.csv dataset:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
#5-4
student_data = {
    "Name": ["Anu", "Binu", "Chinnu", "David", "Eva"],
    "Gender": ["F", "M", "F", "M", "F"],
    "Age": [20, 21, 19, 22, 20]
}
students = pd.DataFrame(student_data)
print("\n4. Student DataFrame:")
print(students)
# First two rows
print("\nFirst two rows:")
print(students.iloc[:2])
# Third row onwards
print("\nThird row onwards:")
print(students.iloc[2:])
# Out:
# 4. Student DataFrame:
#      Name Gender  Age
# 0     Anu      F   20
# 1    Binu      M   21
# 2  Chinnu      F   19
# 3   David      M   22
# 4     Eva      F   20
#
# First two rows:
#    Name Gender  Age
# 0   Anu      F   20
# 1  Binu      M   21
#
# Third row onwards:
#      Name Gender  Age
# 2  Chinnu      F   19
# 3   David      M   22
# 4     Eva      F   20

# %%
#5-5
random_series = pd.Series(np.random.rand(4))
print("\n5(a). Complete random Series:")
print(random_series)
print("\n5(b). Values stored in Series:")
print(random_series.values)
print("\n5(c). First two elements using head():")
print(random_series.head(2))
print("\n5(d). Last three elements using tail():")
print(random_series.tail(3))
# Out:
# 5(a). Complete random Series:
# 0    0.077808
# 1    0.857599
# 2    0.983675
# 3    0.731832
# dtype: float64
#
# 5(b). Values stored in Series:
# [0.07780818 0.85759912 0.98367479 0.73183157]
#
# 5(c). First two elements using head():
# 0    0.077808
# 1    0.857599
# dtype: float64
#
# 5(d). Last three elements using tail():
# 1    0.857599
# 2    0.983675
# 3    0.731832
# dtype: float64

# %%
#5-6
df = pd.DataFrame({
    "Name": ["Asha", "Rahul", "Meena", "John"],
    "Age": [20, 21, 19, 22],
    "Rating": [4.5, 4.0, 4.8, 3.9]
})
print("\n6. DataFrame:")
print(df)
# Transpose
print("\n(a) Transpose:")
print(df.T)
# Row and column labels
print("\n(b) Axes:")
print(df.axes)
# Data types
print("\n(c) Data types:")
print(df.dtypes)
# Check whether DataFrame is empty
print("\n(d) Is DataFrame empty?")
print(df.empty)
# Number of dimensions
print("\n(e) Number of dimensions:")
print(df.ndim)
# Shape
print("\n(f) Shape:")
print(df.shape)
# Total number of elements
print("\n(g) Size:")
print(df.size)
# Values
print("\n(h) Values:")
print(df.values)
# Missing values
print("\n(i) Missing values in each column:")
print(df.isnull().sum())
# Out:
# 6. DataFrame:
#     Name  Age  Rating
# 0   Asha   20     4.5
# 1  Rahul   21     4.0
# 2  Meena   19     4.8
# 3   John   22     3.9
#
# (a) Transpose:
#            0      1      2     3
# Name    Asha  Rahul  Meena  John
# Age       20     21     19    22
# Rating   4.5    4.0    4.8   3.9
#
# (b) Axes:
# [RangeIndex(start=0, stop=4, step=1), Index(['Name', 'Age', 'Rating'], dtype='object')]
#
# (c) Data types:
# Name       object
# Age         int64
# Rating    float64
# dtype: object
#
# (d) Is DataFrame empty?
# False
#
# (e) Number of dimensions:
# 2
#
# (f) Shape:
# (4, 3)
#
# (g) Size:
# 12
#
# (h) Values:
# [['Asha' 20 4.5]
#  ['Rahul' 21 4.0]
#  ['Meena' 19 4.8]
#  ['John' 22 3.9]]
#
# (i) Missing values in each column:
# Name      0
# Age       0
# Rating    0
# dtype: int64

# %%
#6
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

url = "Iris.csv"
df = pd.read_csv(url)

print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#6 2

X = df.drop("Species", axis=1)
y = df["Species"]

print("Features:")
print(X.head())

print("\nTarget:")
print(y.head())
# Out:
# Features:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2
# 3   4            4.6           3.1            1.5           0.2
# 4   5            5.0           3.6            1.4           0.2
#
# Target:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
#6 3
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)
print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (120, 5)
# Testing data: (30, 5)

# %%
#6 4
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print("Feature scaling completed.")
# Out:
# Feature scaling completed.

# %%
#6 5
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
print("k-NN model trained successfully.")
# Out:
# k-NN model trained successfully.

# %%
#6 6
y_pred = knn.predict(X_test)
print("Predicted classes:")
print(y_pred)
# Out:
# Predicted classes:
# ['Iris-setosa' 'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-versicolor' 'Iris-setosa' 'Iris-setosa'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-virginica' 'Iris-setosa']

# %%
#6 7
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
print("Classification Report:")
print(classification_report(y_test, y_pred))
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Accuracy (%):", accuracy * 100)
# Out:
# Confusion Matrix:
# [[10  0  0]
#  [ 0 10  0]
#  [ 0  0 10]]
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00        10
#  Iris-virginica       1.00      1.00      1.00        10
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
# Accuracy: 1.0
# Accuracy (%): 100.0

# %%
#7
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

dataset=pd.read_csv('Cancer_Data.csv')
print(dataset.head())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
x=dataset.drop(['diagnosis'],axis=1).values
y=dataset['diagnosis'].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
classifier=KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=classifier.predict(x_test)

# %%
print(y_pred)
print(y_test)
# Out:
# ['M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M'
#  'M' 'M' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'M'
#  'B' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'M' 'M' 'B'
#  'B' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'M'
#  'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B']
# ['M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M'
#  'M' 'M' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'M'
#  'B' 'M' 'B' 'M' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'M' 'M' 'B'
#  'B' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'B' 'B' 'M'
#  'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'M'
#  'B' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B'
#  'M' 'M' 'B' 'M' 'M' 'B']

# %%
print("Confusion Matrix:",confusion_matrix(y_test,y_pred))
print("Classification Report:",classification_report(y_test,y_pred))
print("Accuracy Score:",accuracy_score(y_test,y_pred))
print("Accuracy Percentage:",accuracy_score(y_test,y_pred)*100,"%")
# Out:
# Confusion Matrix: [[67  0]
#  [ 5 42]]
# Classification Report:               precision    recall  f1-score   support
#
#            B       0.93      1.00      0.96        67
#            M       1.00      0.89      0.94        47
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Accuracy Score: 0.956140350877193
# Accuracy Percentage: 95.6140350877193 %
